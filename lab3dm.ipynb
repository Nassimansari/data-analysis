# %%
import sqlite3
con = sqlite3.connect("accident_data_v1.0.0_2023.db")
cur = con.cursor()

# %%
table_list = [a[0] for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
print(f'Table names are : {table_list}')
# Out:
# Table names are : ['accident', 'casualty', 'vehicle', 'lsoa']

# %%
col_info = cur.execute(f"PRAGMA table_info(accident)")

# %%
col_info.fetchall()
# Out:
# [(0, 'accident_index', '', 0, None, 1),
#  (1, 'accident_year', '', 0, None, 0),
#  (2, 'accident_reference', '', 0, None, 0),
#  (3, 'location_easting_osgr', '', 0, None, 0),
#  (4, 'location_northing_osgr', '', 0, None, 0),
#  (5, 'longitude', '', 0, None, 0),
#  (6, 'latitude', '', 0, None, 0),
#  (7, 'police_force', '', 0, None, 0),
#  (8, 'accident_severity', '', 0, None, 0),
#  (9, 'number_of_vehicles', '', 0, None, 0),
#  (10, 'number_of_casualties', '', 0, None, 0),
#  (11, 'date', '', 0, None, 0),
#  (12, 'day_of_week', '', 0, None, 0),
#  (13, 'time', '', 0, None, 0),
#  (14, 'local_authority_district', '', 0, None, 0),
#  (15, 'local_authority_ons_district', '', 0, None, 0),
#  (16, 'local_authority_highway', '', 0, None, 0),
#  (17, 'first_road_class', '', 0, None, 0),
#  (18, 'first_road_number', '', 0, None, 0),
#  (19, 'road_type', '', 0, None, 0),
#  (20, 'speed_limit', '', 0, None, 0),
#  (21, 'junction_detail', '', 0, None, 0),
# ...

# %%
col_info1 = cur.execute(f"PRAGMA table_info(vehicle)")
col_info1.fetchall()
# Out:
# [(0, 'vehicle_index', '', 0, None, 1),
#  (1, 'accident_index', '', 0, None, 0),
#  (2, 'accident_year', '', 0, None, 0),
#  (3, 'accident_reference', '', 0, None, 0),
#  (4, 'vehicle_reference', '', 0, None, 0),
#  (5, 'vehicle_type', '', 0, None, 0),
#  (6, 'towing_and_articulation', '', 0, None, 0),
#  (7, 'vehicle_manoeuvre', '', 0, None, 0),
#  (8, 'vehicle_direction_from', '', 0, None, 0),
#  (9, 'vehicle_direction_to', '', 0, None, 0),
#  (10, 'vehicle_location_restricted_lane', '', 0, None, 0),
#  (11, 'junction_location', '', 0, None, 0),
#  (12, 'skidding_and_overturning', '', 0, None, 0),
#  (13, 'hit_object_in_carriageway', '', 0, None, 0),
#  (14, 'vehicle_leaving_carriageway', '', 0, None, 0),
#  (15, 'hit_object_off_carriageway', '', 0, None, 0),
#  (16, 'first_point_of_impact', '', 0, None, 0),
#  (17, 'vehicle_left_hand_drive', '', 0, None, 0),
#  (18, 'journey_purpose_of_driver', '', 0, None, 0),
#  (19, 'sex_of_driver', '', 0, None, 0),
# ...

# %%
col_info2 = cur.execute(f"PRAGMA table_info(casualty)")
col_info2.fetchall()
# Out:
# [(0, 'casualty_index', '', 0, None, 1),
#  (1, 'accident_index', '', 0, None, 0),
#  (2, 'accident_year', '', 0, None, 0),
#  (3, 'accident_reference', '', 0, None, 0),
#  (4, 'vehicle_reference', '', 0, None, 0),
#  (5, 'casualty_reference', '', 0, None, 0),
#  (6, 'casualty_class', '', 0, None, 0),
#  (7, 'sex_of_casualty', '', 0, None, 0),
#  (8, 'age_of_casualty', '', 0, None, 0),
#  (9, 'age_band_of_casualty', '', 0, None, 0),
#  (10, 'casualty_severity', '', 0, None, 0),
#  (11, 'pedestrian_location', '', 0, None, 0),
#  (12, 'pedestrian_movement', '', 0, None, 0),
#  (13, 'car_passenger', '', 0, None, 0),
#  (14, 'bus_or_coach_passenger', '', 0, None, 0),
#  (15, 'pedestrian_road_maintenance_worker', '', 0, None, 0),
#  (16, 'casualty_type', '', 0, None, 0),
#  (17, 'casualty_home_area_type', '', 0, None, 0),
#  (18, 'casualty_imd_decile', '', 0, None, 0)]

# %%
col_info3 = cur.execute(f"PRAGMA table_info(lsoa)")
col_info3.fetchall()
# Out:
# [(0, 'objectid', '', 0, None, 1),
#  (1, 'lsoa01cd', '', 0, None, 0),
#  (2, 'lsoa01nm', '', 0, None, 0),
#  (3, 'lsoa01nmw', '', 0, None, 0),
#  (4, 'shape__area', '', 0, None, 0),
#  (5, 'shape__length', '', 0, None, 0),
#  (6, 'globalid', '', 0, None, 0)]

# %%
import pandas as pd

# %%
df_accident = pd.read_sql_query('SELECT * From accident', con)
ac_names = list(df_accident)
print(f'Accident Table columns names are : {ac_names}')
# Out:
# Accident Table columns names are : ['accident_index', 'accident_year', 'accident_reference', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'police_force', 'accident_severity', 'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week', 'time', 'local_authority_district', 'local_authority_ons_district', 'local_authority_highway', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control', 'pedestrian_crossing_physical_facilities', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards', 'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident', 'trunk_road_flag', 'lsoa_of_accident_location']

# %%
df_casualty = pd.read_sql_query('SELECT * From casualty', con)
ac_names1 = list(df_casualty)
print(f'Casualty Table columns names are : {ac_names1}')
# Out:
# Casualty Table columns names are : ['casualty_index', 'accident_index', 'accident_year', 'accident_reference', 'vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty', 'casualty_severity', 'pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_home_area_type', 'casualty_imd_decile']

# %%
df_vehicle = pd.read_sql_query('SELECT * From vehicle', con)
ac_names2 = list(df_vehicle)
print(f'Vehicle Table columns names are : {ac_names1}')
# Out:
# Vehicle Table columns names are : ['casualty_index', 'accident_index', 'accident_year', 'accident_reference', 'vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty', 'casualty_severity', 'pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_home_area_type', 'casualty_imd_decile']

# %%
table_name = 'accident'
query = f"SELECT * FROM {table_name}"

# Execute the query and fetch all rows
cur.execute(query)
all_rows = cur.fetchall()

# Get the row count
row_count = len(all_rows)

print(f"Number of rows in {table_name}: {row_count}")
# Out:
# Number of rows in accident: 461352

# %%
table_name = 'casualty'
query = f"SELECT * FROM {table_name}"

# Execute the query and fetch all rows
cur.execute(query)
all_rows = cur.fetchall()

# Get the row count
row_count = len(all_rows)

print(f"Number of rows in {table_name}: {row_count}")
# Out:
# Number of rows in casualty: 600332

# %%
table_name = 'vehicle'
query = f"SELECT * FROM {table_name}"

# Execute the query and fetch all rows
cur.execute(query)
all_rows = cur.fetchall()

# Get the row count
row_count = len(all_rows)

print(f"Number of rows in {table_name}: {row_count}")
# Out:
# Number of rows in vehicle: 849091

# %%
sql_all = "SELECT * FROM accident JOIN vehicle ON accident.accident_reference = vehicle.accident_reference JOIN casualty ON accident.accident_reference = casualty.accident_reference WHERE accident.accident_year = 2020"

cur.execute(sql_all)
all_rows = cur.fetchall()

# Get the row count
row_count = len(all_rows)

print(f"Number of accident in year 2020 : {row_count}")
# Out:
# Number of accident in year 2020 : 221631

# %%
sql_query = f"SELECT * FROM {table_names[0]}"
accident_df = pd.read_sql_query(sql_query, con)

# %%
display(accident_df)
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 461347  2020991027064           2020          991027064
# 461348  2020991029573           2020          991029573
# 461349  2020991030297           2020          991030297
# 461350  2020991030900           2020          991030900
# 461351  2020991032575           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
sql_query = f"SELECT * FROM {table_names[1]}"
casualty_df = pd.read_sql_query(sql_query, con)

# %%
display(casualty_df)
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
sql_query = f"SELECT * FROM {table_names[2]}"
vehicle_df = pd.read_sql_query(sql_query, con)

# %%
display(vehicle_df)
# Out:
#         vehicle_index accident_index  accident_year accident_reference  \
# 0                   0  2017010001708           2017          010001708
# 1                   1  2017010001708           2017          010001708
# 2                   2  2017010009342           2017          010009342
# 3                   3  2017010009342           2017          010009342
# 4                   4  2017010009344           2017          010009344
# ...               ...            ...            ...                ...
# 849086         849086  2020991030297           2020          991030297
# 849087         849087  2020991030297           2020          991030297
# 849088         849088  2020991030900           2020          991030900
# 849089         849089  2020991030900           2020          991030900
# 849090         849090  2020991032575           2020          991032575
#
#         vehicle_reference  vehicle_type  towing_and_articulation  \
# ...

# %%
accident_df= accident_df.fillna('unknown')

# %%
vehicle_df= vehicle_df.fillna('unknown')

# %%
accident_df = accident_df.fillna('unknown')

# %%
# Rule 1: Speed Limit = 20mph → Accident Severity = Slight
rule1_df = accident_df[accident_df['speed_limit'] == 20]
support_rule1 = len(rule1_df) / len(accident_df)
confidence_rule1 = len(rule1_df[rule1_df['accident_severity'] == 3]) / len(rule1_df)

# Rule 2: Speed Limit = 70mph → Accident Severity = Fatal
rule2_df = accident_df[accident_df['speed_limit'] == 70]
support_rule2 = len(rule2_df) / len(accident_df)
confidence_rule2 = len(rule2_df[rule2_df['accident_severity'] == 1]) / len(rule2_df)

# Rule 3: Pedestrian Crossing Code = Zebra → Casualty Type = Pedestrian
rule3_df = dfall[dfall['pedestrian_location'] == 1]
support_rule3 = len(rule3_df) / len(dfall)
confidence_rule3 = len(rule3_df[rule3_df['casualty_class'] == 3]) / len(rule3_df)

# Calculate Lift
lift_rule1 = confidence_rule1 / support_rule2
lift_rule2 = confidence_rule2 / support_rule2
lift_rule3 = confidence_rule3 / support_rule3

# Print the results
print(f"Support (Rule 1): {support_rule1:.4f}")
print(f"Confidence (Rule 1): {confidence_rule1:.4f}")
print(f"Lift (Rule 1): {lift_rule1:.4f}")

print(f"Support (Rule 2): {support_rule2:.4f}")
print(f"Confidence (Rule 2): {confidence_rule2:.4f}")
print(f"Lift (Rule 2): {lift_rule2:.4f}")

print(f"Support (Rule 3): {support_rule3:.4f}")
print(f"Confidence (Rule 3): {confidence_rule3:.4f}")
print(f"Lift (Rule 3): {lift_rule3:.4f}")
# Out:
# Support (Rule 1): 0.0937
# Confidence (Rule 1): 0.8391
# Lift (Rule 1): 13.9149
# Support (Rule 2): 0.0603
# Confidence (Rule 2): 0.0266
# Lift (Rule 2): 0.4405
# Support (Rule 3): 0.0113
# Confidence (Rule 3): 1.0000
# Lift (Rule 3): 88.1237
